# %% [markdown]
# # MCP Gain Analysis: Raw data
#
# Analysis notebook to process and plot IMAPlo instrument count rates and efficiency and produce plots of the MCP Gain curves
#
# ---
# ### User Info:
# - Double click on a text cell to add comments (comments are input in [markdown](https://www.markdownguide.org/cheat-sheet/))
# - whole notebook can be run using the ```>>``` button
# - new cells of code added using: ```esc,b```
#
# When notebook run is complete:
# 1. Rename Notebook: (double click on datestamped_MCP_Gain file name above)
#     - recommend including info on the test and files processed
# 2. Save Notebook: (ctrl-s) file > Save and Checkpoint
# 3. Print Notebook:  file > Download as > HTML
#
# ---
# This file was auto generated using the pyMAP db_analysis_generator.

# %% [markdown]
# Notebook Operator: YOURNAMEHERE
#
# Comments:

# %%
import pandas as pd
import pyMAP as pm
# %matplotlib notebook

# %% [markdown]
# Load the provided data files, plot The count rate and efficiency variation according to use_x parameter.
# - The loaded data files are combined according to their dateTime index
# - 1min rolling average is applied.
#     - The window of the rolling average can be adjusted using the ```rolling``` parameter.

# %%
fig,axs,dat = pm.tools.cal.raw_mcp_gain(
                            f_ILO_IFB='INPUT IFB DATA FILENAME',
                            f_ILO_RAW_CNT='INPUT RAW_CNT DATA FILENAME',
                            f_ILO_TOF_BD='INPUT IFB DATA FILENAME',
                            home = '../Test Data/Sensor/csv',
                            rolling = 'min',
                            use_x = 'MCP_VM'
                                       )
# Out:
# Loading ../Test Data/Sensor/csv\EMv1_UNHSPLAT_ToF_Functional_MCP_Gain2_20221206_ILO_IFB.csv
# Loading ../Test Data/Sensor/csv\EMv1_UNHSPLAT_ToF_Functional_MCP_Gain2_20221206_ILO_TOF_BD.csv
# Loading ../Test Data/Sensor/csv\EMv1_UNHSPLAT_ToF_Functional_MCP_Gain2_20221206_ILO_RAW_CNT.csv
# <img src="data:image/png;base64,..." width="970.3833333333333">

# %% [markdown]
# ### Comments:
#
#
# # Instrument Status
#
# For reference, use the data loaded in the cell above to plot the instrument status timeseries.

# %%
pm.plt.df_plot_groups(dat,'ILO_EM_status')
# Out:
# <img src="data:image/png;base64,..." width="1000.5333333333333">
# (<Figure size 1000x2800 with 7 Axes>,
#  array([<Axes: ylabel='single_rates [cts/s]'>,
#         <Axes: ylabel='tof_rate[cts/s]'>, <Axes: ylabel='Efficiency'>,
#         <Axes: ylabel='Monitors'>, <Axes: ylabel='volts[V]'>,
#         <Axes: ylabel='Board Temp'>,
#         <Axes: xlabel='dateTime', ylabel='Threshold register'>],
#        dtype=object))

# %% [markdown]
# ### Comments:
